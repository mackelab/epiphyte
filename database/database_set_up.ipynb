# %% [markdown]
# # Set up the database

# %% [markdown]
# This notebook contains the code to set up the database. This only has to be done once.
# Afterwards, the tables are filled and the database can be used.
# Of course it can always be extended.
#
# It is the setup of this particular example data. It has to be adapted to new data sets and applications to fit other projects.

# %% [markdown]
# ### (1) Connect to the database
# Log in with a valid user name and password with add and delete privileges.

# %%
from database.db_setup import *
# Out:
# Please enter DataJoint username:  root
# Please enter DataJoint password:  ···············
# Connecting root@localhost:3306

# %% [markdown]
# ### (2) Populate tables in the correct order
#
# Since some tables depend on others, they need to be populated in the correct order.

# %% [markdown]
# Some tables should already be filled:

# %% [markdown]
# Populating remaining tables

# %%
MovieSession.populate()
ElectrodeUnit.populate()
SpikeTimesDuringMovie.populate()
# Out:
# Min Daq Diff: 0.2 ms, Max Daq Diff: 1.8 ms
# Maximum Error after Event fit: 0.4 ms
# Min Daq Diff: 0.2 ms, Max Daq Diff: 1.6 ms
# Maximum Error after Event fit: 0.4 ms
# Min Daq Diff: 0.4 ms, Max Daq Diff: 1.9 ms
# Maximum Error after Event fit: 0.4 ms
# CSC1 0
# LA
# CSC2 1
# LA
# CSC3 2
# LA
# CSC4 3
# LA
# CSC5 4
# LA
# CSC6 5
# LA
# CSC7 6
# LA
# CSC8 7
# LAH
# CSC9 8
# LAH
# CSC10 9
# LAH
# CSC11 10
# LAH
# CSC12 11
# LAH
# CSC13 12
# LAH
# CSC14 13
# LAH
# CSC15 14
# LAH
# CSC16 15
# LAH
# CSC17 16
# LAH1
# CSC18 17
# LAH1
# CSC19 18
# LAH1
# CSC20 19
# LEC
# CSC21 20
# LEC
# CSC22 21
# LEC
# CSC23 22
# LEC
# CSC24 23
# LEC
# CSC25 24
# LEC
# CSC26 25
# LEC
# CSC27 26
# LEC
# CSC28 27
# LEC
# CSC29 28
# LMH
# CSC30 29
# LMH
# CSC31 30
# LMH
# CSC32 31
# LMH
# CSC33 32
# LMH
# CSC34 33
# LMH
# CSC35 34
# LMH
# CSC36 35
# LMH
# CSC37 36
# LMH
# CSC38 37
# LMH1
# CSC39 38
# LPHC
# CSC40 39
# LPHC
# CSC41 40
# LPHC
# CSC42 41
# LPHC
# CSC43 42
# LPHC
# CSC44 43
# LPHC
# CSC45 44
# LPHC
# CSC46 45
# LPHC
# CSC47 46
# LPHC
# CSC48 47
# LPHC1
# CSC49 48
# LPHC1
# CSC50 49
# LPHC1
# CSC51 50
# LPHC1
# CSC52 51
# LPHC1
# CSC53 52
# LPHC1
# CSC54 53
# RA
# CSC55 54
# RA
# CSC56 55
# RA
# CSC57 56
# RA
# CSC58 57
# RA
# CSC59 58
# RA
# CSC60 59
# RA
# CSC61 60
# RA
# CSC62 61
# RA
# CSC63 62
# RA1
# CSC64 63
# RA1
# CSC65 64
# RA1
------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +-----------+ +--------+ +------------+
# p1             location1      2020-01-01     =BLOB=     =BLOB=     =BLOB=     location      =BLOB=
# p2             character1     2019-12-12     =BLOB=     =BLOB=     =BLOB=     character     =BLOB=
# p2             character2     2019-10-10     =BLOB=     =BLOB=     =BLOB=     character     =BLOB=
#  (Total: 3)

# %%
PatientAlignedMovieAnnotation.populate()
MoviePauses.populate()
MovieSkips.populate()
# Out:
# Added patient aligned label character1 to database.
# Added patient aligned label character2 to database.
# Added patient aligned label location1 to database.
# Added patient aligned label character1 to database.
# Added patient aligned label character2 to database.
# Added patient aligned label location1 to database.
# Added patient aligned label character1 to database.
# Added patient aligned label character2 to database.
# Added patient aligned label location1 to database.
# Min Daq Diff: 0.2 ms, Max Daq Diff: 1.8 ms
# Maximum Error after Event fit: 0.4 ms
# Min Daq Diff: 0.2 ms, Max Daq Diff: 1.6 ms
# Maximum Error after Event fit: 0.4 ms
# Min Daq Diff: 0.4 ms, Max Daq Diff: 1.9 ms
# Maximum Error after Event fit: 0.4 ms
# Min Daq Diff: 0.2 ms, Max Daq Diff: 1.8 ms
# Maximum Error after Event fit: 0.4 ms
# There is a skip in the movie frame playback that is bigger than 25.0 frames.
# The biggest skip is 3775.999999999999 frames.
# Timepoints of skips, in neural_rec_time: [4.51607676e+11 4.54358129e+11]
# Start timepoints: [450860344827.5, 451607713643.75, 454358166272.5]
# Stop timepoints: [451607676021.25, 454358128650.0, 455652150821.5]
#
# Min Daq Diff: 0.2 ms, Max Daq Diff: 1.6 ms
# Maximum Error after Event fit: 0.4 ms
# There is a skip in the movie frame playback that is bigger than 25.0 frames.
# The biggest skip is 12500.999999999993 frames.
# Timepoints of skips, in neural_rec_time: [3.52540344e+11]
# Start timepoints: [350871591947.25, 352540381656.25]
# Stop timepoints: [352540344035.5, 355854791906.0]
#
# Min Daq Diff: 0.4 ms, Max Daq Diff: 1.9 ms
# Maximum Error after Event fit: 0.4 ms
# There is a skip in the movie frame playback that is bigger than 25.0 frames.
# The biggest skip is 7331.999999999994 frames.
# Timepoints of skips, in neural_rec_time: [2.51718674e+11 2.52355905e+11 2.54553286e+11]
# Start timepoints: [249860318500.0, 251718711254.75, 252355942560.25, 254553323269.5]
# Stop timepoints: [251718673633.5, 252355904938.75, 254553285648.0, 254863925563.5]

# %%
UnitLevelDataCleaning.populate()

# %% [markdown]
# ### (3) Visualise structure of database

# %%
erd = dj.ERD(dhv_schema)
erd

# %%
# shows entries made by interacting with the raster plot
ManualAnnotation()
# Out:
# *session_nr    *patient_id    *annotator_id  *label_entry_d *name    x_zero     x_one      y_zero     y_one      additional_inf
# +------------+ +------------+ +------------+ +------------+ +------+ +--------+ +--------+ +--------+ +--------+ +------------+
#
#  (Total: 0)
